# %%
import numpy as np
import matplotlib.pyplot as plt



t=315378.2e-6
y_1=0.1048
y_t1=1.02-3.1e-2
g1= pow( ((np.sqrt(2*y_t1)-np.sqrt(2*y_1))/t),2)
print(g1)

t2=193715.1e-6
y_2=0.1048
y_t2=0.59-3.1e-2
g2= (y_t2-y_2)/(t2**2)
print(g2)

t3=260278.2e-6
y_3=0.1048
y_t3=0.802-3.1e-2
g3= pow( ((np.sqrt(2*y_t3)-np.sqrt(2*y_3))/t3),2)
print(g3)

t4=389016.3e-6
y_4=0.1048
y_t4=1.369-3.1e-2
g4= pow( ((np.sqrt(2*y_t4)-np.sqrt(2*y_4))/t4),2)
print(g4)

t5=268665.8333e-6
y_5=0.1048
y_t5=0.822-3.1e-2
g5= pow( ((np.sqrt(2*y_t5)-np.sqrt(2*y_5))/t5),2)
print(g5)

def ffsnel(tijd,hoogtestandaard,):
    return  (hoogtestandaard-0.1048+0.024)/(tijd**2)


g6=ffsnel(367566e-6,1.238-3.1e-2)
g7=ffsnel(434370.6667e-6,1.607-3.1e-2)
g8=ffsnel(362259.4286e-6,1.124-3.1e-2)
g9=ffsnel(229255.4286e-6,0.665-3.1e-2)
g10=ffsnel(385034e-6,1.328-3.1e-2)
#def bepalingvang(v,y,t,h):
 #   print(2*(h-v*t-y)/t*t)

#bepalingvang(1.433,0.1048,t2,y_t2)

tijd=np.array([t,t2,t3,t4,t5])
hoogte=np.array([y_t1,y_t2,y_t3,y_t4,y_t5,1.238-3.1e-3,1.607-3.1e-3,1.124-3.1e-3,0.665-3.1e-3,1.328-3.1e-3])
gs=np.array([g1,g2,g3,g4,g5,g6,g7,g8,g9,g10])
plt.figure
plt.plot(hoogte,gs,'k.')
plt.show
gem_g=(g1+g2+g3+g4+g5+g6+g7+g8+g9+g10)/10
print(gem_g)

print(g6,g7,g8,g9,g10)
print(80*80*80)
print(200*1850)
# Out:
# 9.046830391614325
# 12.103756545200923
# 9.072006568949805
# 9.170124745211263
# 8.865558788884597
# 9.096086093471213
# 8.335753408610165 7.9246175067792235 7.713064043800145 10.52550434735832 8.203644588303359
# 512000
# 370000
