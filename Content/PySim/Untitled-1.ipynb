# %%
import numpy as np
t=315378.2e-6
v_0= np.sqrt(2*9.8*0.1048)
y_0=0.1048
y_t=1.01

g= ((y_t-v_0*t-y_0)*2)/(t*t)
print(g)
g2= pow( ((np.sqrt(2*y_t)-np.sqrt(2*y_0))/t),2)
print(g2)
# Out:
# 9.112858971964606
# 9.332360763281672
